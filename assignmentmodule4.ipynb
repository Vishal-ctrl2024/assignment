# %% [markdown]
# 1.Explain the key features of python that makes it a popular choice for programming?
#
# Ans= Python is a popular programming language. Its features are:
#  .It is widely used in the industry.
#
#  . It is widely used in the data university.
#
#  . There are many libraries present in python where all optimized and well- written code are already kept.
#  .It has huge active community.
#
#  . Python is very easy to learn as compared to other languages like Javascript, Java, etc.
#
#  .Python is Object-Oriented programming. Python supports object-oriented language and concepts of classes, object encapsulation, etc.
#
#
#  Q2.Describe the role of predefined keywords in python and provide example of how they are used in programme?
#
#  Ans= Python keywords are special reserved and predefined words that have specific meanings and purposes and can't be used for anything but those specific purposes.Keywords are used to define the syntax of the coding. They cannot be used as an identifier, function or variable name.
#
# Example: type, else, while, True, False, etc.
#
# Print("hello world")
#
# Type (a)
#
# hello world
#
# int
#
#
# Q3.Compare and contrast mutable and immutable objects in python with example?
#
# Ans= MUTABLE OBJECTS
#
# 1) Mutable objects are those that allow us to change their value or data.
#
# 2) Mutable objects are widely used in object-oriented programming.
#
# IMMUTABLE OBJECTS
#
# 1) Immutable objects don't allow us to change their value or data.
#
# 2) Immutable objects are common in functional programming.
#
# Similarity between Mutable and Immutable objects is that both Mutable and Immutable data types can be used to store data and can be accessed using the same syntax.
#
# Example of mutable objects.
#
# a= [1, 2,3,4,5,6]
#
# a[4] = "the University"
#
# print(a)
# [1, 2, 3, 4, "the University", 6] #output
#
#
# 4.discuss the different type of operators in pythons and provide example of how they are used?
#
# Ans= Operators are special keywords/symbols that are used to perform operations on values and variables.
#
# Types of operator:
#
# 1) Arithmetic Operators
#
# Addition (+)
#
# Subtraction(-)
#
# Multiplication(*)
#
# Division(/)
#
# Modules (%)
#
# Exponentiation(**)
#
# Example:
# #module
#
# 21%4
#
# 1
#
# #exponentiation
#
# 2**5
#
# 32
#
# Comparison Operator
#
# a = 8
#
# b = 9
#
# # Equal
#
# (a==b)
#
# False
#
# # Not Equal
#
# (a!= b)
#
# True
#
# # Greater Than
# (a > b)
#
# False
#
# # Less Than
#
# (a < b) True
#
# # Greater Than or Equal to
#
# (a >= b)
#
# False
#
# # Less Than or Equal to
#
# 3 <= b \ True
#
# 3) Logical Operators
#
# Logical AND
#
# Logical OR
#
# Logical NOT
#
# Example:
#
# True and False
#
# False
#
# True or False
# True
#
# Bitwise Operator
# a = 10
# b = 9Bitwise AND
# c=a & b
#  c = 8
# # Bitwise OR
# c = a | b
# c = 11
# # Bitwise XOR
# c = a^b
# c = 3
# # Binary NOT
#  ~3
#  4
# # Left Shift
# 35<<3
# 280
# # Right Shift
# 28>>3
# 35
# 5) Assignment Operator
# # Assignment Operator
#  a = 7
# # Addition Assignment
#  b =12
#  b+=5
#  b
#  17
# b =12
#  b-=5
#  b
#  7
# # Multiplication Assignment
# b=7
# b*= 2
# b
# 14
# # Division Assignment
# B=7
# b/=2
# 3.5
# 6) Identity operator
# a = 2
# b = 3
# a is b
# False
# A is not b
# True
# 7) Membership Operator
# a = “
#
# Q5.
# Explain the concept of type casting in python with example?
#
# Ans : Type casting is of two types: Implicit and Explicit type casting
# IMPLICIT TYPE CASTING
# Here, Python converts the datatype into another datatype automatically.
# Example: a = 5
#  Type(a)
#  int
# * EXPLICIT TYPE CASTING
# Here, Python needs user involvement to convert the variable data type
# into the required data type.
# Example: # int variable
# a = 5
# # typecast to float
# n = float(a)
#  print(n)
#  print(type(n))
# 5.0
#
#
#
# Q6) How do conditional statement work in python ? Illustrate
# with exampl?.
# * Ans: If
# The condition can be any expression that evaluates to a Boolean
# value (True or False). If the condition is True, the code block indented
# below the ‘if’ statement will be executed. If the condition is False,
# the code block will be skipped.
# * If-else
# If the condition is True, the code block indented below
# the if statement will be executed, and the code block indented below
# the else statement will be skipped.
# If the condition is False, the code block indented below
# the else statement will be executed, and the code block indented
# below the if statement will be skipped.
# * And same happens with if elif-else and
# Example:
# num = -8
# if num > 0:
#  print("The numbegative
# gative
#
# gative
#
# r is positive.")
# else:
#  print("The number is negative.")
# Output:
# The number is ne
# Q7.Describe the different types of loops in python and their use
# cases with exampl?
#
# Ans : Loop code allow us to execute a  While loop- repeatedly executed a block of code until a condition is
# met.
# Example:
# n=7
# i=7
# while i <n:
#  print (i)
#  i= i+1
# 1
#
# for loop :
# 3
# 4
# 5
# 6pes.
# A) while loop
# B) for loop
# * While loop- repeatedly executed a block of cofor loop:
# It ite
# p
# w
# s
# k
# i
# l
# l
# sl
# l
# sr
#
# r pm, 12/8/2024] Vishal: Wait
# [6:25 pm, 12/8/2024] Vishal: https://meet.google.com/usv-cgxr-cpg
# p
